# %%
import streamlit
import pandas as pd
import os

# %%
df= pd.read_excel('D:\College Files\8th Semester\Project III\Dataverse\Datasets\sales.xlsx')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Spooky\AppData\Local\Temp\ipykernel_1448\1748606495.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df= pd.read_excel('D:\College Files\8th Semester\Project III\Dataverse\Datasets\sales.xlsx')

# %%
df
# Out:
#     ID       Date    Product    Category  C_Price  S_Price  Quantity  Amount  \
# 0    1 2024-01-01  Product B  Category 2    32.45    78.90        10   789.0
# 1    2 2024-01-02  Product A  Category 1    15.75    40.20         5   201.0
# 2    3 2024-01-03  Product C  Category 3    22.00    55.50         3   166.5
# 3    4 2024-01-04  Product B  Category 2    40.20    95.60         7   669.2
# 4    5 2024-01-05  Product A  Category 1    12.60    34.80         8   278.4
# 5    6 2024-01-06  Product C  Category 3    25.30    60.75         6   364.5
# 6    7 2024-01-07  Product B  Category 2    31.80    74.20         9   667.8
# 7    8 2024-01-08  Product A  Category 1    18.25    45.60         4   182.4
# 8    9 2024-01-09  Product C  Category 3    28.00    65.00         7   455.0
# 9   10 2024-01-10  Product B  Category 2    35.00    80.50         5   402.5
# 10  11 2024-01-11  Product A  Category 1    14.90    39.40         6   236.4
# ...
